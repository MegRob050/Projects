# %%
#Program that asks about: Age, Split, how much to put away each month
#Basic principles: 
import random

Current_age=int(input('How old are you? Enter as a whole number. '))

starting_salary=int(input('What is your current salary? Enter as a whole number: '))

Growth_rate= (int(input('By what percent does your salary grow by yearly? ')))/100

retirment_age=int(input('How old will you be when you retire? Enter as a whole number. '))

year_to_save=retirment_age-Current_age

saved_percent=(int(input('By what percent are you saving per year? ')))/100

saved_money_per_year=starting_salary*saved_percent


print('You have',year_to_save,'years to save money')

new_salary=starting_salary
put_away=new_salary*saved_percent
new_age=Current_age
total_savings=0
year_to_save=retirment_age-Current_age

keep_going='yes'

while keep_going=='yes':
    for save in range(1,year_to_save+1):
        new_salary+=Growth_rate*new_salary
        put_away=saved_percent*new_salary
        new_age+=1
        total_savings+=put_away

        print('At the end of year ',save,' and age ',new_age,', your salary will be $',format(new_salary,'.2f'),
              '. You will be putting away $',format(put_away,'.2f'),'.',sep='')

        print("You're total savings will be $"+format(total_savings,'.2f'),'.',sep='')
    keep_going=input("Would you like to try again? ")
# Out:
# How old are you? Enter as a whole number. 22
# What is your current salary? Enter as a whole number. 80000
# By what percent does your salary grow by yearly? 20
# How old will you be when you retire? Enter as a whole number. 64
# By what percent are you saving per year? 12
# You have 42 years to save money
# At the end of year 1 and age 23, your salary will be $96000.00. You will be putting away $11520.00.
# You're total savings will be $11520.00.
# At the end of year 2 and age 24, your salary will be $115200.00. You will be putting away $13824.00.
# You're total savings will be $25344.00.
# At the end of year 3 and age 25, your salary will be $138240.00. You will be putting away $16588.80.
# You're total savings will be $41932.80.
# At the end of year 4 and age 26, your salary will be $165888.00. You will be putting away $19906.56.
# You're total savings will be $61839.36.
# At the end of year 5 and age 27, your salary will be $199065.60. You will be putting away $23887.87.
# ...

# %%
#Program that asks about: Age, Split, how much to put away each month
#Basic principles: 

import random
keep_going='yes'
name_dict={}

while keep_going=='yes':
    Current_age=int(input('How old are you? Enter as a whole number. '))

    starting_salary=int(input('What is your current salary? Enter as a whole number. '))

    Growth_rate= (int(input('By what percent does your salary grow by yearly? ')))/100

    retirment_age=int(input('How old will you be when you retire? Enter as a whole number. '))

    year_to_save=retirment_age-Current_age

    saved_percent=(int(input('By what percent are you saving per year? ')))/100

    saved_money_per_year=starting_salary*saved_percent


    print('You have',year_to_save,'years to save.')

    new_salary=starting_salary
    put_away=new_salary*saved_percent
    new_age=Current_age
    total_savings=0
    year_to_save=retirment_age-Current_age

    
    for save in range(1,year_to_save+1):
        new_salary+=Growth_rate*new_salary
        put_away=saved_percent*new_salary
        new_age+=1
        total_savings+=put_away

        print('At the end of year ',save,' and age ',new_age,', your salary will be $',format(new_salary,'.2f'),
              '. You will be putting away $',format(put_away,'.2f'),'.',sep='')

        print("You're total savings will be $"+format(total_savings,'.2f'),'.',sep='')
        
    dictionary=input("Would you like to save your initial inputs for future reference? If so, enter 'yes': ")

    if dictionary=='yes':
        name=input("Please enter a name to save these results: ")

        name_dict={'Selected Input': name, 'Current Age': Current_age, 'Starting Salary': '$'+format(starting_salary),
               'Growth Rate': '{:.0f}%'.format(Growth_rate*100), 'Retirement Age': retirment_age, 
               'Saved Percentage': '{:.0f}%'.format(saved_percent*100),
               'Years to Save': year_to_save, 'Total Savings': '${:.2f}'.format(total_savings), 
                   'Stock Market Total': '${:.2f}'.format(stock_mkt)}
        
        dict_list=[name_dict]
        dict_list.append(name)
            
    keep_going=input("Would you like to enter a new result? ")
# Out:
# How old are you? Enter as a whole number. 22
# What is your current salary? Enter as a whole number. 80000
# By what percent does your salary grow by yearly? 2
# How old will you be when you retire? Enter as a whole number. 24
# By what percent are you saving per year? 3
# You have 2 years to save.
# At the end of year 1 and age 23, your salary will be $81600.00. You will be putting away $2448.00.
# You're total savings will be $2448.00.
# At the end of year 2 and age 24, your salary will be $83232.00. You will be putting away $2496.96.
# You're total savings will be $4944.96.
# Would you like to save your initial inputs for future reference? If so, enter 'yes': yes
# Please enter a name to save these results: Megan
# Would you like to enter a new result? n

# %%
preview=input("Would you like to view a previously saved reference? If so, enter 'yes': ")

saved_name=input("Please enter the name associated with the reference you wish to view: ")
print('--------------------------------------------------------------------')

for saved_name in name_dict:
    print(saved_name,': ',name_dict[saved_name], sep='')
# Out:
# Would you like to view a previously saved reference? If so, enter 'yes': yes
# Please enter the name associated with the reference you wish to view: Megan
# --------------------------------------------------------------------
# Selected Input: Megan
# Current Age: 22
# Starting Salary: $80000
# Growth Rate: 2%
# Retirement Age: 24
# Saved Percentage: 3%
# Years to Save: 2
# Total Savings: $4944.96

# %%
import random

Current_age=int(input('How old are you? Enter as a whole number: '))

starting_salary=int(input('What is your current salary? Enter as a whole number: '))

Growth_rate= (int(input('By what percent does your salary grow by yearly? ')))/100

retirment_age=int(input('How old will you be when you retire? Enter as a whole number: '))

year_to_save=retirment_age-Current_age

saved_percent=(int(input('By what percent are you saving per year? ')))/100

saved_money_per_year=starting_salary*saved_percent


print('You have',year_to_save,'years to save money')

new_salary=starting_salary
put_away=new_salary*saved_percent
new_age=Current_age
total_savings=0
year_to_save=retirment_age-Current_age

while save==retirment_age:
    for save in range(1,year_to_save+1):
        new_salary+=Growth_rate*new_salary
        put_away=saved_percent*new_salary
        new_age+=1
        total_savings+=put_away

        print('At the end of year ',save,' and age ',new_age,', your salary will be $',format(new_salary,'.2f'),
                      '. You will be putting away $',format(put_away,'.2f'),'.',sep='')

        print("You're total savings will be $"+format(total_savings,'.2f'),'.',sep='')
# Out:
# How old are you? Enter as a whole number. 22
# What is your current salary? Enter as a whole number. 80000
# By what percent does your salary grow by yearly? 20
# How old will you be when you retire? Enter as a whole number. 64
# By what percent are you saving per year? 12
# You have 42 years to save money
# At the end of year 64, your salary will be $96000.00. You will be putting away $11520.00.
# You're total savings will be $11520.00.

# %%
'{:.0f}%'.format(0.12*100)
# >>> '10.12%'
# Out:
# '12%'

# %%
#Program that asks about: Age, Split, how much to put away each month
#Basic principles: 
import random
keep_going='yes'
dict_inputs={}

while keep_going=='yes':

    Current_age=int(input('How old are you? Enter as a whole number: '))

    starting_salary=int(input('What is your current salary? Enter as a whole number: '))

    Growth_rate= (float(input('By what percent does your salary grow by yearly? ')))/100

    retirment_age=int(input('How old will you be when you retire? Enter as a whole number: '))

    year_to_save=retirment_age-Current_age

    saved_percent=(float(input('As a percent, how much are you saving per year? ')))/100

    saved_money_per_year=starting_salary*saved_percent


    print('You have',year_to_save,'years to save money.')

    new_salary=starting_salary
    put_away=new_salary*saved_percent
    return_rate=random.randint(-999,999)/10000
    random_return=return_rate
    ran_put_away=(new_salary*saved_percent)*return_rate
    new_age=Current_age
    total_savings=0
    year_to_save=retirment_age-Current_age
    total_ran_put_away=0
    stock_mkt=0

    for save in range(1,year_to_save+1):
        new_salary+=Growth_rate*new_salary
        put_away=saved_percent*new_salary
        return_rate=random.randint(-999,999)/10000
        ran_put_away=(saved_percent*new_salary)*return_rate
        new_age+=1
        total_savings+=put_away
        stock_mkt+=(put_away+ran_put_away)

        print('At the end of year ',save,' and at age ',new_age,', your salary will be $'+format(new_salary,'.2f'),
              ' and you will have put away $'+format(put_away,'.2f'),'.', sep='')

        if ran_put_away>0:
            print('This has a return rate of ',format(return_rate*100,'.2f')
            ,'%. Thus, giving you a final value of $',format(put_away+ran_put_away, '.2f'),'.', sep='')
            print("As a result, you will have gained $",format(ran_put_away, '.2f'),'.', sep='')
        elif ran_put_away<0:
            print('This has a return rate of ',format(return_rate*100,'.2f')
            ,'%. Thus, giving you a final value of $',format(put_away+ran_put_away, '.2f'),'.', sep='')
            print("As a result, you will have lost $",format(ran_put_away, '.2f'),'.', sep='')
        else:
            print("As a result, you will not have gained or lost any.")

        print("Without putting it in the stock market, you're total savings will be $",format(total_savings, '.2f'),'.', sep='')
        print("With putting it in the stock market, you're total savings will be $",format(stock_mkt, '.2f'),'.', sep='')

        #---------------------------------------------------------------------------------------------------------#

    print('------------------------------------------------------------------------------')    
    create_dict=input("Would you like to save your initial inputs for future reference? If so, enter 'yes': ")
    
    if create_dict=='yes':
        name=input("Please enter a name to save these results: ")
        dict_inputs[name]=['Current Age: '+str(Current_age), 
                           'Starting Salary: '+str('$'+format(starting_salary)),
                           'Growth Rate: ' +str('{:.0f}%'.format(Growth_rate*100)), 
                           'Retirement Age: '+str(retirment_age), 
                            'Saved Percentage: ' + str('{:.0f}%'.format(saved_percent*100)),
                           'Years to Save: ' +str(year_to_save), 
                           'Total Savings without Stock Market: ' +str('${:.2f}'.format(total_savings)), 
                           'Total Savings with Stock Market: ' +str('${:.2f}'.format(stock_mkt))] 
        keep_going=input("Would you like to run the program again? If so, enter 'yes': ")
    else:
        keep_going=input("Instead, would you like to run the program again? If so, enter 'yes': ")
    print('------------------------------------------------------------------------------')
    
        #--------------------------------------------------------------------------------------------------------#
# Out:
# How old are you? Enter as a whole number: 21
# What is your current salary? Enter as a whole number: 80000
# By what percent does your salary grow by yearly? 2
# How old will you be when you retire? Enter as a whole number: 23
# As a percent, how much are you saving per year? 3
# You have 2 year(s) to save money.
# At the end of year 1 and at age 22, your salary will be $81600.00 and you will have put away $2448.00.
# This has a return rate of -9.39%. Thus, giving you a final value of $2218.13.
# As a result, you will have lost $-229.87.
# Without putting it in the stock market, you're total savings will be $2448.00.
# With putting it in the stock market, you're total savings will be $2218.13.
# At the end of year 2 and at age 23, your salary will be $83232.00 and you will have put away $2496.96.
# This has a return rate of 3.76%. Thus, giving you a final value of $2590.85.
# As a result, you will have gained $93.89.
# ...

# %%
keep_going='yes'

while keep_going=='yes':
    
    print('------------------------------------------------------------------------------')
    preview=input("Would you like to view a previously saved reference? If so, enter 'yes': ")
    
    if preview=='yes':

        saved_name=input("Please enter the name associated with the reference you wish to view: ")
        print('------------------------------------------------------------------------------')

        if saved_name in dict_inputs:
            print(saved_name, ':', sep='')
            print(*['' + str(v) for v in dict_inputs[saved_name]], sep='\n')
        
    else:
        keep_going='no'
# Out:
# ------------------------------------------------------------------------------
# Would you like to view a previously saved reference? If so, enter 'yes': yes
# Please enter the name associated with the reference you wish to view: Megan
# ------------------------------------------------------------------------------
# Megan:
# Current Age: 21
# Starting Salary: $80000
# Growth Rate: 2%
# Retirement Age: 23
# Saved Percentage: 3%
# Years to Save: 2
# Total Savings without Stock Market: $4944.96
# Total Savings with Stock Market: $4742.79
# ------------------------------------------------------------------------------
# Would you like to view a previously saved reference? If so, enter 'yes': yes
# Please enter the name associated with the reference you wish to view: Jo
# ------------------------------------------------------------------------------
# Jo:
# Current Age: 20
# Starting Salary: $50000
# Growth Rate: 3%
# Retirement Age: 23
# Saved Percentage: 2%
# Years to Save: 3
# ...
